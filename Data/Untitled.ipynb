# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "clean_data.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Unnamed: 0        id  log_price property_type        room_type  \
# 0           6  11825529   4.418841     Apartment  Entire home/apt
# 1           7  13971273   4.787492   Condominium  Entire home/apt
# 2           9   5385260   3.583519         House     Private room
# 3          11  17423675   5.010635         House  Entire home/apt
# 4          12  14066228   4.248495     Apartment     Private room
#
#                                            amenities  accommodates  bathrooms  \
# 0  {TV,Internet,"Wireless Internet","Air conditio...             3        1.0
# 1  {TV,"Cable TV","Wireless Internet","Wheelchair...             2        1.0
# 2  {"Wireless Internet","Air conditioning",Kitche...             2        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.5
# 4  {TV,Internet,"Wireless Internet",Kitchen,"Free...             2        1.0
#
#    bed_type cancellation_policy  ...  bedrooms beds   zip_lat    zip_lng  \
# ...

# %%
get_column = data[['host_since']]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'log_price', 'property_type', 'room_type',
#        'amenities', 'accommodates', 'bathrooms', 'bed_type',
#        'cancellation_policy', 'cleaning_fee', 'city_x', 'description',
#        'first_review', 'host_has_profile_pic', 'host_identity_verified',
#        'host_response_rate', 'host_since', 'instant_bookable', 'last_review',
#        'latitude', 'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zip', 'bedrooms', 'beds',
#        'zip_lat', 'zip_lng', 'city_y', 'state_id', 'state_name', 'population',
#        'density', 'county_name'],
#       dtype='object')

# %%
get_column.head()
# Out:
#    host_since
# 0  2017-03-03
# 1  2013-05-18
# 2  2017-03-12
# 3  2015-06-11
# 4  2016-05-10

# %%
data['host_since'] = data['host_since'].map(lambda x: x.split(" "))
#data['host_since'] = data['host_since'].map(last_name)
#data['host_since'] = data['host_since'].map(lambda x: x[2:])
#data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-f4f8064980bf> in <module>
# ----> 1 data['host_since'] = data['host_since'].map(lambda x: x.split(" "))
#       2 #data['host_since'] = data['host_since'].map(last_name)
#       3 #data['host_since'] = data['host_since'].map(lambda x: x[2:])
#       4 #data.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3380         """
#    3381         new_values = super(Series, self)._map_values(
# -> 3382             arg, na_action=na_action)
#    3383         return self._constructor(new_values,
#    3384                                  index=self.index).__finalize__(self)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1216
#    1217         # mapper is a function
# ...
