# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "Data/clean_data.csv"

data = pd.read_csv(path)
data.head()
# Out:
#    Unnamed: 0        id  log_price property_type        room_type  \
# 0           6  11825529   4.418841     Apartment  Entire home/apt
# 1           7  13971273   4.787492   Condominium  Entire home/apt
# 2           9   5385260   3.583519         House     Private room
# 3          11  17423675   5.010635         House  Entire home/apt
# 4          12  14066228   4.248495     Apartment     Private room
#
#                                            amenities  accommodates  bathrooms  \
# 0  {TV,Internet,"Wireless Internet","Air conditio...             3        1.0
# 1  {TV,"Cable TV","Wireless Internet","Wheelchair...             2        1.0
# 2  {"Wireless Internet","Air conditioning",Kitche...             2        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.5
# 4  {TV,Internet,"Wireless Internet",Kitchen,"Free...             2        1.0
#
#    bed_type cancellation_policy  ...  bedrooms beds   zip_lat    zip_lng  \
# ...

# %%
data.drop(data.columns[[0]], axis=1, inplace=True)
data.head()
# Out:
#          id  log_price property_type        room_type  \
# 0  11825529   4.418841     Apartment  Entire home/apt
# 1  13971273   4.787492   Condominium  Entire home/apt
# 2   5385260   3.583519         House     Private room
# 3  17423675   5.010635         House  Entire home/apt
# 4  14066228   4.248495     Apartment     Private room
#
#                                            amenities  accommodates  bathrooms  \
# 0  {TV,Internet,"Wireless Internet","Air conditio...             3        1.0
# 1  {TV,"Cable TV","Wireless Internet","Wheelchair...             2        1.0
# 2  {"Wireless Internet","Air conditioning",Kitche...             2        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.5
# 4  {TV,Internet,"Wireless Internet",Kitchen,"Free...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ... bedrooms beds   zip_lat  \
# 0  Real Bed            moderate          True  ...      1.0  1.0  33.97831
# ...

# %%
# GroupBy Ratings and City 
ratings = data[["id","city_y","review_scores_rating","property_type"]]
ratings.head()
# Out:
#          id           city_y  review_scores_rating property_type
# 0  11825529   Marina Del Rey                  97.0     Apartment
# 1  13971273      Los Angeles                  93.0   Condominium
# 2   5385260  Rowland Heights                  90.0         House
# 3  17423675    Hermosa Beach                  97.0         House
# 4  14066228    Redondo Beach                   NaN     Apartment

# %%
city_rating=ratings.dropna()

# %%
city_rating.head()
# Out:
#          id           city_y  review_scores_rating property_type
# 0  11825529   Marina Del Rey                  97.0     Apartment
# 1  13971273      Los Angeles                  93.0   Condominium
# 2   5385260  Rowland Heights                  90.0         House
# 3  17423675    Hermosa Beach                  97.0         House
# 5    583490       Long Beach                 100.0     Apartment

# %%
#Taking the average of scores in Los Angeles 
df1=city_rating.loc[:,["id","city_y","review_scores_rating"]]
la_score = df1[df1.city_y == "Los Angeles"]
la_score.head()
# Out:
#           id       city_y  review_scores_rating
# 1   13971273  Los Angeles                  93.0
# 7    3563677  Los Angeles                  99.0
# 9     851978  Los Angeles                  95.0
# 12  10994968  Los Angeles                  99.0
# 15  12428036  Los Angeles                  92.0

# %%
score_df=city_rating.groupby(['city_y']).median().sort_values('review_scores_rating',ascending=True)[["review_scores_rating"]]
score_df
# Out:
#                      review_scores_rating
# city_y
# Brea                                 20.0
# Lynwood                              82.0
# Mission Hills                        83.0
# Sun Valley                           91.5
# Bellflower                           92.5
# Playa Vista                          93.0
# La Verne                             93.0
# San Gabriel                          93.0
# Hawthorne                            93.0
# Walnut                               93.5
# Montebello                           94.0
# South El Monte                       94.0
# Hacienda Heights                     94.0
# Canyon Country                       94.5
# Inglewood                            95.0
# Paramount                            95.0
# Monterey Park                        95.0
# Lomita                               95.0
# Lancaster                            95.0
# La Puente                            95.0
# West Covina                          95.0
# ...

# %%
score_df.to_csv('Data/score_df')
