# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "Data/clean_data.csv"

axes_data = pd.read_csv(path)
axes_data.head()
# Out:
#    Unnamed: 0        id  log_price property_type        room_type  \
# 0           6  11825529   4.418841     Apartment  Entire home/apt
# 1           7  13971273   4.787492   Condominium  Entire home/apt
# 2           9   5385260   3.583519         House     Private room
# 3          11  17423675   5.010635         House  Entire home/apt
# 4          12  14066228   4.248495     Apartment     Private room
#
#                                            amenities  accommodates  bathrooms  \
# 0  {TV,Internet,"Wireless Internet","Air conditio...             3        1.0
# 1  {TV,"Cable TV","Wireless Internet","Wheelchair...             2        1.0
# 2  {"Wireless Internet","Air conditioning",Kitche...             2        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.5
# 4  {TV,Internet,"Wireless Internet",Kitchen,"Free...             2        1.0
#
#    bed_type cancellation_policy  ...  bedrooms beds   zip_lat    zip_lng  \
# ...

# %%
axes_data.drop(axes_data.columns[[0]], axis=1, inplace=True)
axes_data.head()
# Out:
#    log_price property_type        room_type  \
# 0   4.418841     Apartment  Entire home/apt
# 1   4.787492   Condominium  Entire home/apt
# 2   3.583519         House     Private room
# 3   5.010635         House  Entire home/apt
# 4   4.248495     Apartment     Private room
#
#                                            amenities  accommodates  bathrooms  \
# 0  {TV,Internet,"Wireless Internet","Air conditio...             3        1.0
# 1  {TV,"Cable TV","Wireless Internet","Wheelchair...             2        1.0
# 2  {"Wireless Internet","Air conditioning",Kitche...             2        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.5
# 4  {TV,Internet,"Wireless Internet",Kitchen,"Free...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee city_x  ... bedrooms beds  \
# 0  Real Bed            moderate          True     LA  ...      1.0  1.0
# 1  Real Bed            moderate          True     LA  ...      1.0  1.0
# ...

# %%
axes_df=axes_data.dropna()
axes_df.head()
# Out:
#     log_price property_type        room_type  \
# 1    4.787492   Condominium  Entire home/apt
# 6    4.382027         House     Private room
# 7    4.905275     Apartment  Entire home/apt
# 11   5.220356     Apartment  Entire home/apt
# 15   4.317488     Apartment     Private room
#
#                                             amenities  accommodates  \
# 1   {TV,"Cable TV","Wireless Internet","Wheelchair...             2
# 6   {"Cable TV",Internet,"Wireless Internet","Air ...             2
# 7   {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 11  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 15  {Internet,"Wireless Internet",Kitchen,"Free pa...             8
#
#     bathrooms  bed_type cancellation_policy  cleaning_fee city_x  ...  \
# 1         1.0  Real Bed            moderate          True     LA  ...
# 6         1.0  Real Bed              strict          True     LA  ...
# ...

# %%
df1 = axes_df[["city_y","review_scores_rating","property_type","neighbourhood","number_of_reviews","host_since","room_type","log_price","bedrooms","bathrooms"]]
df1
# Out:
#                city_y  review_scores_rating    property_type    neighbourhood  \
# 1         Los Angeles                  93.0      Condominium         Downtown
# 6            Van Nuys                  98.0            House     Sherman Oaks
# 7         Los Angeles                  99.0        Apartment         Downtown
# 11             Venice                  96.0        Apartment           Venice
# 15        Los Angeles                  92.0        Apartment         Westlake
# 19             Venice                  93.0            House           Venice
# 21        Los Angeles                 100.0        Apartment        Los Feliz
# 23        Los Angeles                  89.0        Apartment        Hollywood
# 24        Los Angeles                 100.0        Apartment        Hollywood
# 28           Monrovia                  80.0            House          Arcadia
# 29            Burbank                  84.0        Apartment          Burbank
# ...

# %%
df2=df1.sort_values('host_since',ascending=True)
df2.dropna().head()
# Out:
#              city_y  review_scores_rating property_type  neighbourhood  \
# 20338   Culver City                  80.0   Condominium    Culver City
# 19285   Los Angeles                 100.0     Apartment   Mid-Wilshire
# 14405  Santa Monica                  96.0     Apartment   Santa Monica
# 11979   Los Angeles                  97.0         House    Silver Lake
# 11021   Los Angeles                 100.0         House  Laurel Canyon
#
#        number_of_reviews  host_since        room_type  log_price  bedrooms  \
# 20338                  2  2008-06-27  Entire home/apt   4.804021       2.0
# 19285                  2  2008-07-31  Entire home/apt   4.787492       1.0
# 14405                 16  2008-09-17     Private room   4.976734       1.0
# 11979                 91  2008-09-23  Entire home/apt   5.549076       3.0
# 11021                  3  2008-10-02     Private room   4.369448       1.0
#
#        bathrooms
# 20338        2.0
# 19285        1.0
# 14405        1.0
# ...

# %%
#df2['year']=pd.DatetimeIndex(df2['host_since']).year
#df2.head()

# %%
la_df=df2.loc[df2['city_y']=="Los Angeles"]
la_df
# Out:
#             city_y  review_scores_rating property_type  \
# 19285  Los Angeles                 100.0     Apartment
# 11979  Los Angeles                  97.0         House
# 11021  Los Angeles                 100.0         House
# 402    Los Angeles                 100.0         House
# 6787   Los Angeles                 100.0         House
# 15910  Los Angeles                  97.0         House
# 4841   Los Angeles                  93.0         House
# 20855  Los Angeles                  97.0         House
# 20145  Los Angeles                  94.0         House
# 9935   Los Angeles                  96.0         House
# 19828  Los Angeles                  98.0         House
# 9133   Los Angeles                  95.0     Apartment
# 12919  Los Angeles                  94.0         House
# 16070  Los Angeles                  94.0         Cabin
# 11138  Los Angeles                  87.0         House
# 4459   Los Angeles                  97.0         House
# ...

# %%
la_df2=la_df[["neighbourhood","property_type","host_since","log_price"]]
la_df2
# Out:
#                    neighbourhood property_type  host_since  log_price
# 19285               Mid-Wilshire     Apartment  2008-07-31   4.787492
# 11979                Silver Lake         House  2008-09-23   5.549076
# 11021              Laurel Canyon         House  2008-10-02   4.369448
# 402                Laurel Canyon         House  2008-10-02   4.454347
# 6787               Laurel Canyon         House  2008-10-02   4.369448
# 15910                   Mid-City         House  2009-01-16   3.988984
# 4841                    Mid-City         House  2009-01-16   5.293305
# 20855                   Mid-City         House  2009-01-16   4.234107
# 20145                   Mid-City         House  2009-01-16   3.663562
# 9935                    Mid-City         House  2009-01-16   4.605170
# 19828                Culver City         House  2009-02-12   4.219508
# 9133                 Silver Lake     Apartment  2009-02-12   4.553877
# ...

# %%
la_df3=la_df2.groupby(['neighbourhood']).mean().sort_values('log_price',ascending=False)
la_df3
# Out:
#                            log_price
# neighbourhood
# Pacific Palisades           6.785923
# West Athens                 5.593944
# Pasadena                    5.576336
# Bel Air/Beverly Crest       5.530208
# Studio City                 5.357209
# Venice                      5.306623
# Beverly Hills               5.206047
# Cahuenga Pass               5.154427
# Laurel Canyon               5.101662
# Downtown                    4.941833
# Hollywood Hills             4.899700
# Westwood                    4.897855
# West Hollywood              4.852703
# Hawthorne                   4.828314
# Baldwin Hills               4.821333
# Brentwood                   4.815605
# Silver Lake                 4.781392
# Skid Row                    4.763874
# Elysian Valley              4.738229
# West Los Angeles            4.733696
# Glendale                    4.718705
# Atwater Village             4.703433
# Willowbrook                 4.693825
# Los Feliz                   4.679722
# ...

# %%
la_df2.to_csv("Data/bedbath.csv")

# %%
la_df3=la_df2.drop(["Yurt"])
la_df3.to_csv("Data/pricetype.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-166-3735d615b705> in <module>
# ----> 1 la_df3=la_df2.drop(["Yurt"])
#       2 la_df3.to_csv("Data/pricetype.csv")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
axes_df2=axes_df.groupby(['property_type']).mean().sort_values('number_of_reviews',ascending=False)
axes_df2
# Out:
#                     log_price  accommodates  bathrooms  cleaning_fee  \
# property_type
# Chalet               4.499810      5.000000   1.000000      1.000000
# Yurt                 4.581195      3.000000   1.000000      0.666667
# Cabin                4.491390      2.222222   1.194444      0.777778
# In-law               4.499810      2.000000   1.000000      1.000000
# Tent                 3.963622      1.571429   1.428571      0.571429
# Treehouse            5.340455      5.000000   2.000000      1.000000
# Guest suite          4.602250      2.250000   1.041667      0.750000
# Bed & Breakfast      4.250251      2.336000   1.556000      0.576000
# Other                4.703793      3.389831   1.177966      0.805085
# Bungalow             4.755334      2.903553   1.038071      0.949239
# Tipi                 5.246118      4.666667   1.000000      1.000000
# Loft                 4.814916      3.567961   1.191748      0.868932
# ...

# %%
multiaxes_df=axes_df2.drop(["Chalet"])
multiaxes_df
# Out:
#                     log_price  accommodates  bathrooms  cleaning_fee  \
# property_type
# Yurt                 4.581195      3.000000   1.000000      0.666667
# Cabin                4.491390      2.222222   1.194444      0.777778
# In-law               4.499810      2.000000   1.000000      1.000000
# Tent                 3.963622      1.571429   1.428571      0.571429
# Treehouse            5.340455      5.000000   2.000000      1.000000
# Guest suite          4.602250      2.250000   1.041667      0.750000
# Bed & Breakfast      4.250251      2.336000   1.556000      0.576000
# Other                4.703793      3.389831   1.177966      0.805085
# Bungalow             4.755334      2.903553   1.038071      0.949239
# Tipi                 5.246118      4.666667   1.000000      1.000000
# Loft                 4.814916      3.567961   1.191748      0.868932
# Camper/RV            4.340922      2.823529   1.058824      0.823529
# ...

# %%
multiaxes_df.to_csv('Data/multiaxes_df.csv')
